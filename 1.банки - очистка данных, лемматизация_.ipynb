# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px">
#
# Лариса привет! 👋 Поздравляю с первым выполненным проектом.
#
# Меня зовут Рустам Муртазин, и я буду делать ревью проектной работы по предобработке данных. Давай будем общаться на **«ты»**. Если это неприемлемо, обязательно напиши мне в комментариях — мы перейдем на **«вы»**.
#
# Ты проделала большую работу над проектом, однако в любом деле всегда можно можно что-то улучшить. Моя основная цель — не показать, что где-то совершены какие-либо ошибки, а поделиться своим опытом, который поможет тебе в дальнейших работах. Далее в файле ты сможешь увидеть мои комментарии, постарайся учесть их при выполнении следующих заданий.
#
# Обрати внимание в первую очередь на те, что помечаны <span style="color:red">красным цветом</span>. После их доработки проект будет принят. <span style="color:green">Зеленым цветом</span> отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. <span style="color:orange">Оранжевым цветом</span> выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: если ты **что-то меняешь** в проекте по моим рекомендациям — **пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее».
#
# В целом работа хорошая, видно, что ты старалась. Дорабатывай комментарии и отправляй работу на повторное ревью, я буду ждать 😉
#
# </div>
#
# </div>
# <span style="color:blue">Рустам, привет! Рада знакомству.
# Огромное спасибо за комментарии - столько всего полезного!
#
# </span>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 </h2>
#
# Спасибо, за быструю и качественную доработку комментариев! Все моменты были исправлены, так что работу я принимаю. Ты большая молодец, что исправила все комментарии (и оранжевые тоже). Приятно быть полезным)
#
# В общем получилась классная работа. Благодарю за старания и интерес и желаю успехов в дальнейших проектах 😊
#
# </div>

# %% [markdown]
# # Оглавление
#    [Исследование надёжности заёмщиков. Введение](#шаг-0)
# 1. [Шаг 1. Загрузка файла с данными и изучение общей информации](#шаг-1)
# 2. [Шаг 2. Предобработка данных](#шаг-2)
#     1. [Обработка пропусков](#шаг-2-1)
#     2. [Обработка артефактов](#шаг-2-2)
#     3. [Обработка дубликатов](#шаг-2-3)
#     4. [Лемматизация](#шаг-2-4)
#     5. [Категоризация данных](#шаг-2-5)
# 3. [Шаг 3. Ответы на вопросы](#шаг-3)
#     1. [Есть ли зависимость между наличием детей и возвратом кредита в срок?](#шаг-3-1)
#     2. [Есть ли зависимость между семейным положением и возвратом кредита в срок?](#шаг-3-2)
#     3. [Есть ли зависимость между уровнем дохода и возвратом кредита в срок?](#шаг-3-3)
#     4. [Как разные цели кредита влияют на его возврат в срок?](#шаг-3-4)
#     5. [Насколько влияют пол, тип занятости и уровень образования  клиентов на возвращаемость кредита?](#шаг-3-5)
# 4. [Шаг 4. Общий вывод](#шаг-4)
# 5. [Рекомендации](#шаг-5)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 </h2>
#
# Супер, отличное оглавление 😊
#
# </div>

# %% [markdown]
# ## Исследование надёжности заёмщиков. Введение <a name="шаг-0"></a>

# %% [markdown]
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели **кредитного скоринга** — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.
#
# Данные предоставленые в формате CSV и содержат следующие данные:
# - children — количество детей в семье
# - days_employed — общий трудовой стаж в днях
# - dob_years — возраст клиента в годах
# - education — уровень образования клиента
# - education_id — идентификатор уровня образования
# - family_status — семейное положение
# - family_status_id — идентификатор семейного положения
# - gender — пол клиента
# - income_type — тип занятости
# - debt — имел ли задолженность по возврату кредитов
# - total_income — ежемесячный доход
# - purpose — цель получения кредита
#
# Цель исследования -   определить какие категории потребителей являются наиболее надёжными заёмщиками.
#
# Для достижения цели необходима предварительная обработка массива данных:
# - устранение пропущенных значений
# - устранение дубликатов
# - определение аномальных значений и устранение ошибок
# - категоризация и лемматизация данных для упрощения работы с широким спектром переменных
#
# Далее очищенные данные будут проанализированы и позволят ответить на следующие вопросы:
# 1. Есть ли зависимость между наличием детей и возвратом кредита в срок?
# 2. Есть ли зависимость между семейным положением и возвратом кредита в срок?
# 3. Есть ли зависимость между уровнем дохода и возвратом кредита в срок?
# 4. Как разные цели кредита влияют на его возврат в срок?
# 5. Насколько влияют пол, тип занятости и уровень образования клиентов на возвращаемость кредита?
#
# В результате анализа будут определены основные характеристики групп потребителей, которые наиболее взаимосвязаны с ключевым показателем  - процентом возвращаемости кредита.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Перед началом основного блока исследования полезно описать данные, с которыми работаешь, какие шаги планируешь выполнить, четко сформулировать цель работы. Здесь также можно добавить кликабельное [оглавление](https://fooobar.com/questions/49721/markdown-to-create-pages-and-table-of-contents) 🙃
#
# </div>
# <span style="color:blue"> принято и сделано!
#
# </span>

# %% [markdown]
# ## Шаг 1. Загрузка файла с данными и изучение общей информации <a name="шаг-1"></a>

# %%
import pandas as pd

try:
    df = pd.read_csv('/datasets/data.csv') #загружаем результаты запросов
except:
    df = pd.read_csv('C:/Users/Larissa Olifirova/Desktop/Яндекс практикум/2.Предобработка данных/data.csv')

# %% [markdown]
# Для оценки структуры таблицы используем атрибут columns :

# %%
df.columns
# Out:
# Index(['children', 'days_employed', 'dob_years', 'education', 'education_id',
#        'family_status', 'family_status_id', 'gender', 'income_type', 'debt',
#        'total_income', 'purpose'],
#       dtype='object')

# %% [markdown]
# Названия колонок не нуждаются в редактировании: имена корректны, пробелы отсутствуют.
# Выгружаем несколько случайно выбранных строк:

# %%
df.sample(10)
# Out:
#        children  days_employed  dob_years education  education_id  \
# 11203         1   -3976.904933         31   среднее             1
# 9965          1   -1363.224720         26   среднее             1
# 12243         0   -2793.635709         49   среднее             1
# 12094         0   -2590.184762         29   среднее             1
# 8052          0   -4087.638517         47   СРЕДНЕЕ             1
# 16157         0   -1868.294260         48    высшее             0
# 20370         1   -2621.903545         39   среднее             1
# 1967          0    -525.037419         25   среднее             1
# 14013         0    -246.719370         25   среднее             1
# 8189          0            NaN         60   среднее             1
#
#                family_status  family_status_id gender income_type  debt  \
# 11203       гражданский брак                 1      M   компаньон     0
# 9965   Не женат / не замужем                 4      M   сотрудник     0
# ...

# %% [markdown]
# Получаем общую информацию о содержимом датафрейма, используя метод info():

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# Предварительно оцениваем ситуацию по должникам:

# %%
df['debt'].mean()
# Out:
# 0.08088269454123112

# %% [markdown]
# Процент невозврата почти 8%. Предстоит узнать, какие факторы влияют на этот показатель.

# %% [markdown]
# ### Вывод

# %% [markdown]
# * Названия столбцов и типы данных не требуют корректировки.
# * В столбцах с трудовым стажем days_employed некорректные  значения с огромным разбросом.
# * Столбец дети children содержит отрицательные числа.
# * В таблице 21 525 строк и 12 столбцов.
# * В столбцах days_employed, total_income есть пустые ячеки.
# * С небольшими корректировками данные пригодны для исследования.
# * Процент невозврата кредитов 8%

# %% [markdown]
# ## Шаг 2. Предобработка данных <a name="шаг-2"></a>

# %% [markdown]
# ### Обработка пропусков  <a name="шаг-2-1"></a>

# %%
df.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# Пропуски присутствуют только в двух столбцах days_employed - стаж клиента банка в днях  и total_income - ежемесячный доход клиента.

# %% [markdown]
# ### Заполнение пропущенных значений  total_income медианными значениями

# %%
mediana_income = df['total_income'].median()
df['total_income'].fillna(mediana_income, inplace=True)
df['total_income'] = df['total_income'].astype('int')  #также переводим значения из типа Float в Integer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      21525 non-null  int32
#  11  purpose           21525 non-null  object
# dtypes: float64(1), int32(1), int64(5), object(5)
# memory usage: 1.9+ MB

# %% [markdown]
# #### Устранение пропущенных значений в столбце days_employed

# %%
df.sort_values(by = 'days_employed').head() #сортируем таблицу
# Out:
#        children  days_employed  dob_years education  education_id  \
# 16335         1  -18388.949901         61   среднее             1
# 4299          0  -17615.563266         61   среднее             1
# 7329          0  -16593.472817         60    высшее             0
# 17838         0  -16264.699501         59   среднее             1
# 16825         0  -16119.687737         64   среднее             1
#
#          family_status  family_status_id gender income_type  debt  \
# 16335  женат / замужем                 0      F   сотрудник     0
# 4299   женат / замужем                 0      F   компаньон     0
# 7329   женат / замужем                 0      F   сотрудник     0
# 17838  женат / замужем                 0      F   сотрудник     0
# 16825  женат / замужем                 0      F   сотрудник     0
#
#        total_income                       purpose
# 16335        186178      операции с недвижимостью
# 4299         122560                 покупка жилья
# ...

# %%
df['days_employed'].describe() #общее описание столбца о стаже работы клиента
# Out:
# count     19351.000000
# mean      63046.497661
# std      140827.311974
# min      -18388.949901
# 25%       -2747.423625
# 50%       -1203.369529
# 75%        -291.095954
# max      401755.400475
# Name: days_employed, dtype: float64

# %%
df['days_employed'].isna().sum()
# Out:
# 2174

# %% [markdown]
# Описание отражает некорректные цифру максимального и минимальных значений дней стажа. Предположим, что существует связь значений days_employed с возрастом. Прежде определим, сколько пропусков в столбце:

# %% [markdown]
# Раздробим столбец на множество промежутков и посмотрим, где именно сосредоточены основные значения, для этого используем pandas cut:

# %%
df['experience'] = pd.cut(df['days_employed'],500)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Кстати, здесь ты можешь задать параметр `labels`, тогда группы будут называться более красиво))
#
# </div>
# <span style="color:blue"> выставляю одну ось (х), но вторая не получается. А вот с гистограммой появилась надпись frequency на оси у.
#
# </span>

# %%
df.groupby('experience')['days_employed'].count().plot(figsize=(18,5)).set_xlabel('группы experience');

# %%
df.groupby('experience')['days_employed'].count().plot(kind='hist', figsize=(10,3), bins=50).set_xlabel('experience');

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Решение неплохое, но можно поступить красивее, построй график [hist](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html), при этом увеличь кол-во `bins`
#
# </div>
# <span style="color:blue"> да, сделала выше
#
# </span>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 </h2>
#
# То что нужно! Ниже оставил пример реализации в комбинации с библиотекой `matplotlib`, с ней вы познакомитесь на следующем этапе)
#
# </div>

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (14, 5))
df['days_employed'].hist(bins = 100, color = 'green')
plt.title('Гистограмма распределения days_employed', fontsize = 14)
plt.ylabel('Частота')
plt.xlabel('days_employed');

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Для того, чтобы не показывать вспомогательные выводы python типа `<matplotlib.axes._subplots.AxesSubplot at 0x7f5feaf7fc90>`, можно в конце строки добавить точку с запятой 😉
#
# </div>
# <span style="color:blue"> спасибо!
#
# </span>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Не забывай указывать заголовки и названия осей на графиках. Это необходимо для того, чтобы понять какие именно показатели отображены на графиках (комментарий ко всему проекту).
#
# </div>

# %%
df.groupby('experience')['days_employed'].count().head(25)  #более детально исследуем пик, полученный на графике
# Out:
# experience
# (-18809.094, -17548.661]       2
# (-17548.661, -16708.372]       0
# (-16708.372, -15868.084]       3
# (-15868.084, -15027.795]       8
# (-15027.795, -14187.506]      10
# (-14187.506, -13347.218]      21
# (-13347.218, -12506.929]      25
# (-12506.929, -11666.64]       49
# (-11666.64, -10826.352]       65
# (-10826.352, -9986.063]       80
# (-9986.063, -9145.774]       114
# (-9145.774, -8305.485]       136
# (-8305.485, -7465.197]       201
# (-7465.197, -6624.908]       253
# (-6624.908, -5784.619]       291
# (-5784.619, -4944.331]       557
# (-4944.331, -4104.042]       775
# (-4104.042, -3263.753]      1173
# (-3263.753, -2423.465]      1853
# (-2423.465, -1583.176]      2524
# (-1583.176, -742.887]       3851
# (-742.887, 97.402]          3915
# (97.402, 937.69]               0
# (937.69, 1777.979]             0
# (1777.979, 2618.268]           0
# Name: days_employed, dtype: int64

# %% [markdown]
# Основные значения лежат в промежутке от минус 5000 до нуля.

# %%
df.groupby('experience')['days_employed'].count().tail(10) 
#также посмотрим на конец графика, где значения days_employed не пропущены
# Out:
# experience
# (393352.513, 394192.802]    39
# (394192.802, 395033.091]    40
# (395033.091, 395873.38]     51
# (395873.38, 396713.668]     44
# (396713.668, 397553.957]    41
# (397553.957, 398394.246]    45
# (398394.246, 399234.534]    35
# (399234.534, 400074.823]    38
# (400074.823, 400915.112]    29
# (400915.112, 401755.4]      48
# Name: days_employed, dtype: int64

# %% [markdown]
# Определеяем есть ли зависимость days_employed от возраста клиента:

# %%
df.groupby('experience')['dob_years'].agg(['count', 'median', 'mean']).head(25)
# Out:
#                           count  median       mean
# experience
# (-18809.094, -17548.661]      2    61.0  61.000000
# (-17548.661, -16708.372]      0     NaN        NaN
# (-16708.372, -15868.084]      3    60.0  61.000000
# (-15868.084, -15027.795]      8    60.0  60.125000
# (-15027.795, -14187.506]     10    59.0  60.200000
# (-14187.506, -13347.218]     21    57.0  57.333333
# (-13347.218, -12506.929]     25    57.0  56.760000
# (-12506.929, -11666.64]      49    52.0  53.306122
# (-11666.64, -10826.352]      65    52.0  52.323077
# (-10826.352, -9986.063]      80    51.0  50.712500
# (-9986.063, -9145.774]      114    49.5  50.192982
# (-9145.774, -8305.485]      136    47.0  47.720588
# (-8305.485, -7465.197]      201    47.0  47.666667
# (-7465.197, -6624.908]      253    46.0  46.328063
# (-6624.908, -5784.619]      291    46.0  46.185567
# (-5784.619, -4944.331]      557    43.0  44.061041
# (-4944.331, -4104.042]      775    42.0  43.243871
# ...

# %%
df.groupby('experience')['dob_years'].agg(['median', 'mean']).head(25).plot(figsize=(18,5)).set_ylabel('возраст');

# %%
df.groupby('experience')['dob_years'].agg(['count', 'median', 'mean']).tail(80)
# Out:
#                           count  median       mean
# experience
# (334532.304, 335372.593]     44    60.0  57.795455
# (335372.593, 336212.882]     32    60.0  59.468750
# (336212.882, 337053.171]     38    60.5  58.921053
# (337053.171, 337893.459]     45    60.0  58.800000
# (337893.459, 338733.748]     38    61.0  60.236842
# ...                         ...     ...        ...
# (397553.957, 398394.246]     45    60.0  57.044444
# (398394.246, 399234.534]     35    59.0  58.742857
# (399234.534, 400074.823]     38    62.0  61.105263
# (400074.823, 400915.112]     29    57.0  56.137931
# (400915.112, 401755.4]       48    59.0  58.333333
#
# [80 rows x 3 columns]

# %% [markdown]
# ### Заполнение пропущенных значений в days_employed на основе данных о возрасте

# %% [markdown]
# Смотрим, каким показателем можно воспользоваться для замены пропущенных значений. Из графика ниже видно, что именно медиана явно привязана к градации пенсионер-не пенсионер и ей можно воспользоваться для заполнения пустующих ячеек:

# %%
df.groupby('dob_years')['days_employed'].agg(['median', 'mean']).plot(figsize=(15,5)).set_xlabel('возраст');

# %% [markdown]
# Далее собственно заполняем пропуски медианными значениями по стажу для каждой возрастной категории:

# %%
df['days_employed'] = df['days_employed'].fillna(df.groupby('dob_years')['days_employed'].transform('median'))

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Отличное решение!
#
# </div>

# %%
df.head(15)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Показатель стажа клиента в днях days_employed обратно пропорционален возрасту клиента dob_years. Если взять модули значений рабочего стажа и значения возраста, то получится прямая и логичная зависимость. При этом здесь мы видим возраст от 39 до 60. Если смотреть последние строки таблицы, где значения стажа принимают максимальные положительные значения, то мы увидим, что сюда вошли клиенты практически пенсионного возраста. Таким образом явно отслеживается наличие взаимосвязи между возрастом и стажем, что позволило заполнить пропущенные значения медианными значениями по возрастным группам.

# %% [markdown]
# ### Обработка артефактов <a name="шаг-2-2"></a>

# %% [markdown]
# Анализируем категорию children:

# %%
df['children'].value_counts()
# Out:
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64

# %% [markdown]
# В первом столбце присутствуют некорректные цифры: -1 и 20 детей, поэтому рассмотрим эти строки детальнее. Для этого используем методы head() и tail():

# %%
df.sort_values(by='children').head()
# Out:
#        children  days_employed  dob_years education  education_id  \
# 15435        -1   -3614.220232         40    высшее             0
# 9574         -1   -2710.419901         28    высшее             0
# 6385         -1  370215.476226         48   среднее             1
# 20393        -1  355157.107212         69   среднее             1
# 11617        -1    -370.827130         27   среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 15435       гражданский брак                 1      F    сотрудник     0
# 9574         женат / замужем                 0      M  госслужащий     0
# 6385          вдовец / вдова                 2      F    пенсионер     0
# 20393  Не женат / не замужем                 4      F    пенсионер     0
# 11617        женат / замужем                 0      F    компаньон     0
#
#        total_income                                purpose  \
# 15435         98127                        сыграть свадьбу
# ...

# %%
df.sort_values(by='children').tail()
# Out:
#        children  days_employed  dob_years education  education_id  \
# 3302         20   -1601.523962         35   среднее             1
# 5020         20    -231.783475         37   среднее             1
# 15313        20    -133.690801         56   Среднее             1
# 16795        20   -2530.540521         29   среднее             1
# 15812        20   -3438.044106         42   среднее             1
#
#                family_status  family_status_id gender  income_type  debt  \
# 3302   Не женат / не замужем                 4      F  госслужащий     0
# 5020        гражданский брак                 1      M    компаньон     0
# 15313        женат / замужем                 0      F    компаньон     0
# 16795        женат / замужем                 0      M    компаньон     0
# 15812        женат / замужем                 0      F    сотрудник     0
#
#        total_income                 purpose              experience
# ...

# %% [markdown]
# Очевидных взаимосвязей между некорректными значениями в столбце children и другими данными нет, доспускаем, что при выгрузке данных произошла технологическая ошибка, которая требует обсуждения и решения. Но в данном случае поменяем некорректные значения на 0 с помощью метода replace:

# %%
df['children'] = df['children'].replace([-1,20], 0)

# %%
df['children'].value_counts()
# Out:
# 0    14272
# 1     4818
# 2     2055
# 3      330
# 4       41
# 5        9
# Name: children, dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# При выполнении работы важно соблюдать структуру, которая дана в описании проекта, она поможет тебе построить последовательное исследование. Поэтому перенеси, пожалуйста, обработку аномальных значений во второй раздел.
#
# </div>
# <span style="color:blue"> сделано!
# </span>

# %% [markdown]
# Анализируем категорию gender:

# %%
df['gender'].value_counts()
# Out:
# F      14236
# M       7288
# XNA        1
# Name: gender, dtype: int64

# %% [markdown]
# В столбце gender есть некая категория XNA. Поменяем XNA на F, как более популярную категорию, поскольку значение всего одно.

# %%
df['gender'] = df['gender'].replace('XNA', 'F')

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# Отмечу здесь красным, перенеси, пожалуйста, решения согласно структуре работы
#
# </div>
#
# </div>
# <span style="color:blue"> сделано!
# </span>

# %% [markdown]
# Анализируем категорию education, где встречаются слова с прописными буквами:

# %%
df['education']= df['education'].str.lower() #приводим записи в единый стиль написания и исключим заглавные буквы

# %%
df['education'].value_counts()
# Out:
# среднее                15233
# высшее                  5260
# неоконченное высшее      744
# начальное                282
# ученая степень             6
# Name: education, dtype: int64

# %% [markdown]
# ### Вывод
#
# * Устранена ошибка в столбце "дети" children. Отрицательные и нереалистичные значения заменены на ноль.
# * Клиенты с 5 детьми не имеют долга перед банком (100% возвращаемости). Относительно ненадёжные потребители кредитов с точки зрения возврата кредита - бездетная категория с процентом задолеженнности 7,5%.
# * Устранена ошибка в указании категориальных переменных в столбце "пол" gender. Некорректное значение отнесено к наибольшей группе.
# * Категория клиентов, не обременённых браком наиболее всего склонны к неисполнению своих обязательств перед банком: доля невозвратных кредитов по ним - 9,7%.  Клиенты категории вдовец/вдова являются наиболее ответственной категорией: доля невозвратных кредитов по ним - 6,6%.
# * Приведены в единый тип написания (строчными буквами) данные столбца "образование" education.
# * Процент просроченных кредитов выше у клиентов с доходами ниже среднего.

# %% [markdown]
# ### Обработка дубликатов <a name="шаг-2-3"></a>

# %%
df.duplicated().sum()
# Out:
# 71

# %%
df[df.duplicated(keep=False)].head(50) #Выведем список дубликатов:
# Out:
#       children  days_employed  dob_years education  education_id  \
# 120          0   -1987.334781         46   среднее             1
# 520          0   -1601.523962         35   среднее             1
# 541          0  333953.491811         57   среднее             1
# 554          0  349414.537285         60   среднее             1
# 680          1   -1420.586863         30    высшее             0
# 1005         0  354981.718187         62   среднее             1
# 1191         0  343984.931910         61   среднее             1
# 1431         0   -1847.778632         41   среднее             1
# 1511         0  331245.976666         58    высшее             0
# 1681         0  333953.491811         57   среднее             1
# 2052         0  331245.976666         58   среднее             1
# 2254         0    -919.865413         54    высшее             0
# 2545         0  349414.537285         60   среднее             1
# ...

# %%
#df.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ### Вывод

# %% [markdown]
# Все полученные в качестве дублирующихся строки не содержат значений стажа и дохода. 71 дублирующаяся строка - очень малое число, составляющее лишь 0.2% от общего числа строк.
# Но мы не можем быть уверены, что эти строки являются истинными дубликатами.
# Поэтому дубли не будут удалены.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Возможно, до анализа дубликатов стоит привести данные к общему виду (к нижнему регистру), ведь это может влиять на их кол-во
#
# </div>
#
# </div>
# <span style="color:blue"> дублирование проанализировала теперь после приведения к единому регистру и цифра 54 изменилась на 71. И вот вопрос, кстати: у нас ведь ни одгого id и по этой логике строки, написанные другим регистром, наверняка не являются дубликатом (ну я вот так думаю). Поэтому у меня и возникли большие сомнения, что правильнее делать сначала: приводить к регистру или проверять дубликаты.
#
# </span>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 </h2>
#
# Не совсем понял вопроса( В общем смысле всегда необходимо сначала работать с видом/типом данных, а потом только смотреть на дубликаты. Если останутся вопросы, свяжись со мной через куратора, разберем вопрос))
#
# </div>

# %% [markdown]
# ### Лемматизация  <a name="шаг-2-4"></a>

# %% [markdown]
# Столбец purpose заполнен неоднородным текстом с различными целями клиентов. Проанализировать их быстро и качественно без помощи лемматизации очень сложно. Также используем контейнер Counter для подсчёта встречаемости каждой категории:

# %%
from pymystem3 import Mystem
m = Mystem()

def lemmas(purpose):
    lem_list = ' '.join(m.lemmatize(purpose))
    return lem_list

df['lemma_purpose'] = df['purpose'].apply(lemmas)

# %%
from collections import Counter
Counter(df['lemma_purpose'])
# Out:
# Counter({'покупка   жилье \n': 647,
#          'приобретение   автомобиль \n': 462,
#          'дополнительный   образование \n': 462,
#          'сыграть   свадьба \n': 774,
#          'операция   с   жилье \n': 653,
#          'образование \n': 447,
#          'на   проведение   свадьба \n': 777,
#          'покупка   жилье   для   семья \n': 641,
#          'покупка   недвижимость \n': 624,
#          'покупка   коммерческий   недвижимость \n': 664,
#          'покупка   жилой   недвижимость \n': 607,
#          'строительство   собственный   недвижимость \n': 635,
#          'недвижимость \n': 634,
#          'строительство   недвижимость \n': 620,
#          'на   покупка   подержать   автомобиль \n': 479,
#          'на   покупка   свой   автомобиль \n': 505,
#          'операция   с   коммерческий   недвижимость \n': 651,
#          'строительство   жилой   недвижимость \n': 626,
#          'жилье \n': 647,
#          'операция   со   свой   недвижимость \n': 630,
# ...

# %%
def lemmas(purpose):
    lem_list = ' '.join(m.lemmatize(purpose))
    if 'недвижимость' in lem_list:
        return 'недвижимость'
    if 'жилье' in lem_list:
        return 'недвижимость'
    if 'автомобиль' in lem_list:
        return 'автомобиль'
    if 'свадьба' in lem_list:
        return 'свадьба'
    if 'образование' in lem_list:
        return 'образование'

df['lemma_purpose'] = df['purpose'].apply(lemmas)
from collections import Counter
Counter(df['lemma_purpose'])
# Out:
# Counter({'недвижимость': 10840,
#          'автомобиль': 4315,
#          'образование': 4022,
#          'свадьба': 2348})

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Жирный плюс! Это один из сложнейших этапов проекта, справилась на отлично
#
# </div>

# %%
df.head()
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# 2   женат / замужем                 0      M   сотрудник     0        145885
# 3   женат / замужем                 0      M   сотрудник     0        267628
# 4  гражданский брак                 1      F   пенсионер     0        158616
#
#                       purpose                experience lemma_purpose
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# * Метод лемматизации позволил распределить данные по целям для получения кредитов на 4 крупные категории, что значительно упростит работу по анализу  категории  purpose и позволит избежать множества ошибок.
# * Основная цель для получения кредита - приобретение недвижимости - практически половина клиентов берут займы для покупки жилых или коммерческих помещений.

# %% [markdown]
# ### Категоризация данных <a name="шаг-2-5"></a>

# %% [markdown]
# Для лучшей визуализации распределим доходы по двум основным категориям меньше среднего и больше среднего. В качестве среднего будет использовано среднее значение по ряду total_income

# %%
mean_income = df['total_income'].mean()

# %%
mean_income
# Out:
# 165158.94276422763

# %%
def income_category(total_income):
    if total_income > mean_income:
        return 'выше среднего'
    if total_income < mean_income:
        return 'ниже среднего'
df['income_group'] = df['total_income'].apply(income_category)

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Тоже стоит перенести
#
# </div>
# <span style="color:blue">Перенесла!
#
# </span>

# %% [markdown]
# ### Вывод
#
# Размах по доходам довольно велик, поэтому принятие некого среднего, разделяющего все доходы на две основные категории значительно упрощает анализ и визуализацию результатов.

# %% [markdown]
# ## Шаг 3. Ответы на вопросы <a name="шаг-3"></a>

# %% [markdown]
# ### Есть ли зависимость между наличием детей и возвратом кредита в срок? <a name="шаг-3-1"></a>

# %% [markdown]
# Для анализа зависимости между наличием долга и другими факторами будет использоваться метод сводных таблиц.

# %%
df['children'].value_counts()
# Out:
# 0    14272
# 1     4818
# 2     2055
# 3      330
# 4       41
# 5        9
# Name: children, dtype: int64

# %% [markdown]
# Теперь можно чётко отследить убывающий тренд: большинство клиентов банка не имеют детей.
# Далее анализируем, как эти показатели влияют на возвращаемость кредитов:

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Супер, молодец, что пользуешься `pivot_table`. Здесь можно было выполнить короче, для этого не указывай в таблице `columns`, а в `values` передавай `debt` и в `aggfunc` ищи сразу `mean`
#
# </div>
# <span style="color:blue"> Круто! Я попробовала реализовать (две следующие строки), это правильно?
#
# </span>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 </h2>
#
# Не совсем: на первой строке ты создаешь новый столбец датафрейма `pivot_children`, хотя его еще нет. Тебе необходимо создать сначала сам датафрейм, т.е так
#
# </div>

# %%
# pivot_children['debt_percentage'] = df.pivot_table(index=['children'], values='debt', aggfunc='mean')

# pivot_children['debt_percentage'].map('{:.1%}'.format)

pivot_children = df.pivot_table(index=['children'], values='debt', aggfunc='mean') # код ревьюера
pivot_children.columns = ['debt_percentage']  # код ревьюера
pivot_children['debt_percentage'].map('{:.1%}'.format)  # код ревьюера
# Out:
# children
# 0    7.5%
# 1    9.2%
# 2    9.4%
# 3    8.2%
# 4    9.8%
# 5    0.0%
# Name: debt_percentage, dtype: object

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 </h2>
#
# У тебя отличная работа!
#
# Может тебе будет интересно: для улучшения визуализации датафрейма, можно пользоваться [style](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html) библиотеки `pandas`. Там много прикольных штук для того, чтобы сделать датафрейм красивее 😊
# Например, в нашем случае, чтобы выводить результат в процентах, а не в долях, можно прописать следующее:
#
# `pivot_children.style.format({'debt_percentage': '{:.2%}'})`
#
# </div>

# %%
pivot_children = df.pivot_table(index=['children'], columns='debt', values='dob_years', aggfunc='count')
pivot_children['debt_percentage'] = pivot_children[1] / (pivot_children[1] + pivot_children[0])
pivot_children['debt_percentage'] = pivot_children['debt_percentage'].map('{:.1%}'.format)
pivot_children.sort_values(by='debt_percentage', ascending=False)
# Out:
# debt            0       1 debt_percentage
# children
# 5             9.0     NaN            nan%
# 4            37.0     4.0            9.8%
# 2          1861.0   194.0            9.4%
# 1          4374.0   444.0            9.2%
# 3           303.0    27.0            8.2%
# 0         13200.0  1072.0            7.5%

# %% [markdown]
# ### Есть ли зависимость между семейным положением и возвратом кредита в срок?<a name="шаг-3-2"></a>

# %%
pivot_family_status = df.pivot_table(index=['family_status'], columns='debt', values='children', aggfunc='count')
pivot_family_status['debt_percentage'] = pivot_family_status[1] / (pivot_family_status[1] + pivot_family_status[0])
pivot_family_status['debt_percentage'] = pivot_family_status['debt_percentage'].map('{:.1%}'.format)
pivot_family_status.sort_values(by='debt_percentage', ascending=False)
# Out:
# debt                       0    1 debt_percentage
# family_status
# Не женат / не замужем   2539  274            9.7%
# гражданский брак        3789  388            9.3%
# женат / замужем        11449  931            7.5%
# в разводе               1110   85            7.1%
# вдовец / вдова           897   63            6.6%

# %% [markdown]
# ### Вывод
#
# * Категория клиентов, не обременённых браком наиболее всего склонны к неисполнению своих обязательств перед банком: доля невозвратных кредитов по ним - 9,7%.
# * Клиенты категории вдовец/вдова являются наиболее ответственной категорией: доля невозвратных кредитов по ним - 6,6%.

# %% [markdown]
# ### Есть ли зависимость между уровнем дохода и возвратом кредита в срок? <a name="шаг-3-3"></a>

# %%
pivot_income = df.pivot_table(index=['income_group'], columns='debt', values='children', aggfunc='count')
pivot_income['debt_percentage'] = pivot_income[1] / (pivot_income[1] + pivot_income[0])
pivot_income['debt_percentage'] = pivot_income['debt_percentage'].map('{:.1%}'.format)
pivot_income.sort_values(by='debt_percentage', ascending=False)
# Out:
# debt               0     1 debt_percentage
# income_group
# ниже среднего  12690  1144            8.3%
# выше среднего   7094   597            7.8%

# %% [markdown]
# ### Вывод
#
# Процент просроченных кредитов выше у клиентов с доходами ниже среднего - 8,3%.

# %% [markdown]
# ### Как разные цели кредита влияют на его возврат в срок? <a name="шаг-3-4"></a>

# %% [markdown]
# Проанализируем взаимосвязь целей кредита с его возвратом. Здесь 0  - кредит был возвращён в срок, 1 - у клиента есть задолженность перед банком

# %%
pivot_purpose = df.pivot_table(index=['lemma_purpose'], columns='debt', values='children', aggfunc='count')
pivot_purpose['debt_percentage'] = pivot_purpose[1] / (pivot_purpose[1] + pivot_purpose[0])
pivot_purpose['debt_percentage'] = pivot_purpose['debt_percentage'].map('{:.1%}'.format)
pivot_purpose.sort_values(by='debt_percentage', ascending=False)
# Out:
# debt               0    1 debt_percentage
# lemma_purpose
# автомобиль      3912  403            9.3%
# образование     3652  370            9.2%
# свадьба         2162  186            7.9%
# недвижимость   10058  782            7.2%

# %% [markdown]
# ### Вывод
#
# Процент невозврата не превышает 10%. Наиболее высокий процент должников среди клиентов, использующих кредит на приобретение автомобиля - 9,3%. Наиболее низкий процент долгов среди получивших кредит на коммерческую или жилую недвижимость - 7,2%.

# %% [markdown]
# ### Насколько влияют пол, тип занятости и уровень образования  клиентов на возвращаемость кредита? <a name="шаг-3-5"></a>

# %% [markdown]
# Сопоставим несколько факторов вместе  и проверим как они влияют на наличие задолженности. Определим как пол, образование и доход вместе влияют на кредитную историю.

# %%
pivot_education = df.pivot_table(index=['education', 'gender', 'income_type'], columns='debt', values='children', aggfunc='count')
pivot_education['debt_percentage'] = pivot_education[1] / (pivot_education[1] + pivot_education[0])
pivot_education['debt_percentage'] = pivot_education['debt_percentage'].map('{:.1%}'.format)
pivot_education.sort_values(by='debt_percentage', ascending=False)
# Out:
# debt                                             0      1 debt_percentage
# education           gender income_type
# высшее              F      безработный         1.0    NaN            nan%
#                     M      студент             1.0    NaN            nan%
# ученая степень      M      пенсионер           1.0    NaN            nan%
#                     F      пенсионер           1.0    NaN            nan%
#                            госслужащий         1.0    NaN            nan%
# среднее             M      безработный         NaN    1.0            nan%
#                     F      в декрете           NaN    1.0            nan%
# неоконченное высшее M      пенсионер           5.0    NaN            nan%
#                            госслужащий        22.0    NaN            nan%
# начальное           M      пенсионер          20.0    NaN            nan%
#                            госслужащий         4.0    NaN            nan%
# ...

# %% [markdown]
# ### Вывод
#
# * Наиболее критичная для выдачи кредитов аудитория, представленная мужчинами с начальным образованием, относящихся к категории по типу занятости "сотрудник" - 16,5%.
# * В таблице есть более кретичный процент невыплат - 25% (женщины, госслужащие с начальным образованием), однако эта группа представлена всего четырьмя клиентами и не может быть репрезентативной для серьезного вывода.
# * Наибольшее доверие у кредитного отдела банка должны вызвать пенсионеры, женщины с неоконченным высшим образованием: доля невозвратных кредитов по ним  - 2,8%.
# * Потребители кредитов банка представлены в основном людьми со средним образованием. Люди с учёной степенью практически не берут займы

# %% [markdown]
# ## Шаг 4. Общий вывод <a name="шаг-4"></a>
#
# В данном проекте была проведена предварительная обработка массива данных:
# - устранены пропущенные значения в столбцах по стажу и ежемесячным доходам
# - повторяющиеся строки или дубликаты не были устранены, поскольку отсутствует идентификатор
# - определены аномальные значения и устранены  ошибки, связанные с некорректным вводом данных
# - проведена категоризация и лемматизация данных для упрощения работы с широким спектром переменных: данные собрана в группы, что значительно упростило их визуализацию и восприятие.
#
# Основные ошибки устранены с помощью предобработки в Python. Некоторые ошибки могут быть системными и тербуют диалога с разработчиками и другими владельцами процессов по выгрузке или по внесению данных в БД.
#
# Клиенты с 5 детьми не имеют долга перед банком (100% возвращаемости). Относительно ненадёжные потребители кредитов с точки зрения возврата кредита - бездетная категория с процентом задолженнности 7,5%. Также категория клиентов, не обременённых браком наиболее всего склонны к неисполнению своих обязательств перед банком: доля невозвратных кредитов по ним - 9,7%.
# Таким образом заявки людей, не связанных какими-либо семейными обязательствами должны быть рассмотренны более тщательно.
#
# Процент просроченных кредитов выше у клиентов с доходами ниже среднего (145 000)
#
# Основная цель для получения кредита - приобретение недвижимости - практически половина клиентов берут займы для покупки жилых или коммерческих помещений. И именно эти займы возвращаются вбанк чаще всего: наиболее низкий процент долгов среди получивших кредит на коммерческую или жилую недвижимость - 7,2%. Наиболее высокий процент должников среди клиентов, использующих кредит на приобретение автомобиля - 9,3%.
#
# Процент невозврата кредитов в среднем составляет  8%. По некоторым категориям клиентов этот процент значительно выше: наиболее критичная для выдачи кредитов аудитория, представленная мужчинами с начальным образованием, относящихся к категории по типу занятости "сотрудник", где процент невыплат составляет 16,5%.
# Наибольшее доверие у кредитного отдела банка должны вызвать пенсионеры, женщины с неоконченным высшим образованием: доля невозвратных кредитов по ним - 2,8%.

# %% [markdown]
# ## Рекомендации <a name="шаг-1"></a>
#
# * Данные содержали ошибки с некорректными показателями по количеству детей, возраста клиентов, пола. Рекомендуется при вводе данных в форму предложить оператору/клиенту всплывающие  окна  со списками всех показателей, где  имеют место категориальные переменные. Это значительно ускорит работу оператора и упростит действия клиента, а также серьёзно сократит время на анализ и обработку данных.
#
# * В целом провести аудит правил валидации формы заявки на сервере. Для заполнения форм должны быть чёткие правила, при нарушениии которых система не должна принимать заявку.
#
# * В наборе данных отстутсвуют id, что не позволяет чётко определить дубликаты. Идентификаторы обязательно необходимо ввести в дальнейшем.
#
# * Несмотря на наличие корреляции между возрастом и стажем клиентов, показатель стажа имеет отрицательные значения. Здесь необходма проработка вопроса с разработчиками и архитекоторами базы данных. Рекомендуется более упрощенный подсчёт стажа в годах.

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# Старайся расписывать общий вывод более детально. Это лицо твоего продукта, аналитической деятельности, и от того, насколько хорошо и детально ты его распишешь, будут судить о тебе как о профессионале. В общий вывод стоит добавить результаты работ на втором и третьем шагах, как были обрабатаны пропуски, их возможные причины и тд. Это позволит людям, у которых нет времени вникать в работу, понять что было сделано и как. Также полезно выделить блок «Рекомендации».
#
# </div>
# <span style="color:blue"> Добавлено!
#
# </span>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 </h2>
#
# Другое дело! Пример полного и развернутого вывода 👏
#
# </div>

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px">
#
# У тебя получилась очень хорошая работа! Многие моменты сделаны просто прекрасно. Ты показываешь отличное владение изучаемым материалом: уверенно пользуешься pandas, умеешь подготавливать, очищать, обогощать данные. На протяжении всей работы чувствуется глубина проработки задачи и это безусловный плюс для нас.
#
# Остались небольшие доработки:
#
# - Необходимо исправить структуру работы;
# - В шаге 4 необходимо дополнить общий вывод.
#
# Жду твоих исправлений, у тебя все получится 😊
#
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл;
# - [x]  файл изучен;
# - [x]  определены пропущенные значения;
# - [x]  заполнены пропущенные значения;
# - [x]  есть пояснение, какие пропущенные значения обнаружены;
# - [x]  описаны возможные причины появления пропусков в данных;
# - [x]  объяснено, по какому принципу заполнены пропуски;
# - [x]  заменен вещественный тип данных на целочисленный;
# - [x]  есть пояснение, какой метод используется для изменения типа данных и почему;
# - [ ]  удалены дубликаты;
# - [x]  есть пояснение, какой метод используется для поиска и удаления дубликатов;
# - [x]  описаны возможные причины появления дубликатов в данных;
# - [x]  выделены леммы в значениях столбца с целями получения кредита;
# - [x]  описан процесс лемматизации;
# - [x]  данные категоризированы;
# - [x]  есть объяснение принципа категоризации данных;
# - [x]  есть ответ на вопрос: "Есть ли зависимость между наличием детей и возвратом кредита в срок?";
# - [x]  есть ответ на вопрос: "Есть ли зависимость между семейным положением и возвратом кредита в срок?";
# - [x]  есть ответ на вопрос: "Как разные цели кредита влияют на его возврат в срок?";
# - [x]  в каждом этапе есть выводы;
# - [x]  есть общий вывод.
